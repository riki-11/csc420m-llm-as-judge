# %% [markdown]
# # LLM-as-a-Judge for English-to-Filipino Translations: Prompt-Engineered LLM Judge
# Enrique Lejano & Monica Manlises | CSC420M G01

# %% [markdown]
# ## I. Setup

# %% [markdown]
# Uncomment if need to install packages.

# %%
# %pip install -U langchain langchain-google-genai python-dotenv langchain-core "langchain-chroma>=0.1.2" google-genai chromadb langchain-chroma scikit-learn libretranslatepy langchain_community --quiet
# %load_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2

from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.rate_limiters import InMemoryRateLimiter
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report
from libretranslatepy import LibreTranslateAPI
import pandas as pd
import numpy as np
import re

from prompt_judge_main import load_training_set, load_test_set, prepare_zeroshot_prompt, evaluate_with_prompt_engineering, parse_rating, measure_standard_metrics

load_dotenv(override=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# True

# %% [markdown]
# ### Load Dataset and Preprocessing

# %%
training_set_path = "../datasets/training.csv"
test_set_path = "../datasets/test.csv"

# %% [markdown]
# Load training set

# %%
training_df = load_training_set(training_set_path)
training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 561 entries, 0 to 562
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   English           561 non-null    object
#  1   Filipino-Correct  561 non-null    object
#  2   Filipino-Flawed   561 non-null    object
#  3   Remarks           561 non-null    object
# dtypes: object(4)
# memory usage: 21.9+ KB

# %% [markdown]
# Load test set

# %%
test_df = load_test_set(test_set_path)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   English    57 non-null     object
#  1   Filipino   57 non-null     object
#  2   Rating     57 non-null     float64
#  3   Remarks 1  57 non-null     object
#  4   Remarks 2  57 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 2.7+ KB

# %% [markdown]
# Setup standardized rate limiter for Gemini API requests to avoid exceeding rate limits.

# %%
rate_limiter = InMemoryRateLimiter(
    requests_per_second=0.25,  # 1 request every 4 seconds
    check_every_n_seconds=0.1,
    max_bucket_size=1.0        # No piling up of surplus tokens
)

# %% [markdown]
# ## II. Zeroshot Prompting

# %% [markdown]
# Prepare LLM and prompt

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    rate_limiter=rate_limiter
)

final_prompt = prepare_zeroshot_prompt(llm)
final_prompt
# Out:
# ChatPromptTemplate(input_variables=['english', 'filipino'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='\n    You are a professional translation evaluator. You must assess a Filipino translation based on:\n    - Adequacy: Does the Filipino translation preserve the meaning of the original sentence?.\n    - Fluency: Is it natural, smooth, and grammatically correct to be easily understood by a native speaker?.\n    - Lexical Choice: Are the words contextually accurate and culturally appropriate?.\n\n    For each input: \n    - Adequacy rating (1-5) + detailed reasoning for your score (cite words or phrases from the translation),\n    - Fluency rating (1-5) + reasoning,\n    - Lexical Choice rating (1-5) + reasoning.\n    - Overall rating (1-5).\n\n    All the reasonings should be detailed.\n    Output Format:\n    English Sentence: ...\n    Filipino Translation: ...\n    Adequacy: (1-5) + [reasoning citing specific words/phrases]\n    Fluency: (1-5) + [reasoning citing specific words/phrases]\n    Lexical Choice: (1-5) + [reasoning citing specific words/phrases]\n    Overall Rating: ...\n\n    Do not preamble.\n    '), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['english', 'filipino'], input_types={}, partial_variables={}, template='English Sentence: {english}\nFilipino Translation: {filipino}'), additional_kwargs={})])

# %% [markdown]
# Format message and test with single input

# %%
messages = final_prompt.format_messages(
    english="With what would you use a \"wah-wah pedal?\"",
    filipino="Ano ang gagamitin mo ng \"wah-wah pedal?\"",
)

response = llm.invoke(messages)
print(response.content)
# Out:
# English Sentence: With what would you use a "wah-wah pedal?"
# Filipino Translation: Ano ang gagamitin mo ng "wah-wah pedal?"
# Adequacy: 3 - The translation captures the basic question of what one would use with a wah-wah pedal. However, the preposition "with" is not accurately translated, leading to a slightly awkward phrasing. The Filipino sentence directly translates to "What will you use of 'wah-wah pedal'?" which isn't entirely correct.
# Fluency: 3 - The sentence is grammatically correct but sounds slightly unnatural. A more fluent phrasing might reorder the words or use a different construction.
# Lexical Choice: 5 - The term "wah-wah pedal" is correctly retained, and the other words are common and appropriate.
# Overall Rating: 3

# %% [markdown]
# Run LLM prompt on entire training set.

# %%
test_df_prompt_engineered = test_df.copy()

test_df_prompt_engineered['pred_raw'] = test_df_prompt_engineered.apply(
    lambda r: evaluate_with_prompt_engineering(llm, final_prompt, r['English'], r['Filipino']),
    axis=1,
)

# %% [markdown]
# Save results (full response + extracted rating) to `.csv` file

# %%
test_df_prompt_engineered['pred_rating'] = test_df_prompt_engineered['pred_raw'].apply(parse_rating)

test_df_prompt_engineered.to_csv('../results/prompt_engineered_ratings.csv', index=False)
test_df_prompt_engineered
# Out:
#                                               English  \
# 0   The children laughed and played under the afte...
# 1            She took a break to gather her thoughts.
# 2   The algorithm efficiently identifies patterns ...
# 3   Data normalization helps improve model perform...
# 4   alam mo ma'am masaya naman topics natin sa phi...
# 5                         It's raining cats and dogs.
# 6   The party of the first part shall not be held ...
# 7                  Thank you for coming to the event.
# 8   Despite her exhaustion, she finished the repor...
# 9           That designer bag costs an arm and a leg.
# 10  I didn’t want to go to the dentist, but I had ...
# 11  Mark accidentally let the cat out of the bag a...
# 12  I won’t be able to attend the meeting later be...
# 13     Darkness is not heresy. It lies within us all.
# 14  This would be easier if blood came in more col...
# 15  This guy right here is Shadow, and he's kinda ...
# 16  Stealth is not your thing. But it's adorable y...
# 18  Cheddar cheese got its name from a village in ...
# 19  Which of the following tools is LEAST likely t...
# 20          With what would you use a "wah-wah pedal?
# 21  Which of the following dental topics is develo...
# 23  The Bloons are back and better than ever! Get ...
# 24  Sea of Thieves is a smash-hit pirate adventure...
# 25  The Binding of Isaac: Rebirth is a randomly ge...
# 26  Welcome to a new world! In Monster Hunter: Wor...
# 28  For so long, you and me been finding each othe...
# 29             I can't stop smiling when you're there
# 30                 I just want to be your everything.
# 31  If I give you all my life, would you still be ...
# 33  A stack overflow happens when there is too muc...
# 34  The database index speeds up data retrieval by...
# 35  The kernel handles low-level operations in the...
# 36  The address bus carries memory addresses to th...
# 37  Jollibee is a famous fast food restaurant in t...
# 38   Filipinos visit their relatives during holidays.
# 39  Filipinos often use the expression "po" and "o...
# 40  Adobo is one of the most popular dishes in the...
# 41  The hospitability of Filipinos are known world...
# 42  We love to celebrate fiestas and gatherings wi...
# 43  Adobo and sinigang are just some of the delici...
# 44  Eating rice with almost every meal is part of ...
# 46  The nurse inserted the IV incorrectly, causing...
# 47  The patient was given penicillin to prevent in...
# 48  To be able to start fasting, you have to stop ...
# 49  After being checked up, you have to be admitte...
# 51  I always make it a priority to set aside time ...
# 52  One of the purposes of life is to help others ...
# 53  I exclusively use Spotify to listen to music s...
# 54  I have a large collection of non-fiction books...
# 56  Taking crazy things seriously is a serious was...
# 57  Things outside you are projections of what’s i...
# 58  Some men are born mediocre, some men achieve m...
# 59  Mother died today. Or maybe yesterday; I can't...
# 60  The wave returns to the ocean, where it came f...
# 61  Sick of tea?! That's like being sick of breath...
# 62  I wanted to invite my youngest to go get some ...
# 63  That person has no more respect or love for yo...
#
#                                              Filipino  Rating  \
# 0   Ang mga bata ay nagtawanan at naglaro sa ilali...     4.0
# 1                 Nagpahinga siya para mag-isip-isip.     4.0
# 2   Mabisang kinikilala ng algoritmo ang mga patte...     3.0
# 3   Tumutulong sa pagpabuti ng model ang normalisa...     5.0
# 4   You know, ma'am, we have a lot of fun philosop...     4.0
# 5                             Umuulan ng pusa at aso.     1.0
# 6   Ang partido ng unang bahagi ay hindi mananagot...     4.0
# 7                   Salamat sa pagpunta sa kaganapan.     5.0
# 8   Sa kabila ng kanyang pagod, natapos niya ang u...     5.0
# 9                Napakamahal ng designer bag na 'yan.     5.0
# 10  Ayoko sanang pumunta sa dentista, pero kailang...     4.0
# 11  Hindi sinasadyang nailabas ni Mark ang pusa mu...     3.0
# 12  Hindi ako makakadalo sa meeting mamaya dahil m...     5.0
# 13  Hindi kasalanan ang kadiliman. Nagsisinungalin...     2.0
# 14  Ito ay magiging mas madali kung ang dugo ay du...     2.0
# 15  Ang lalaking ito dito ay si Shadow, at siya an...     1.0
# 16  Ang pagnanakaw ay hindi bagay sa iyo. Ngunit i...     1.0
# 18  Ang nayon na pinagkuhanan ng pangalan ng chedd...     3.0
# 19  Alin sa mga sumusunod ang PINAKABIHIRANG ginag...     5.0
# 20            Ano ang gagamitin mo ng "wah-wah pedal?     1.0
# 21  Alin sa mga sumusunod na paksa sa ngipin ang a...     2.0
# 23  Ang Bloons ay bumalik at mas mahusay kaysa dat...     3.0
# 24  Ang Sea of Thieves ay isang smash-hit na pirat...     2.0
# 25  Ang The Binding of Isaac: Rebirth ay isang ran...     2.0
# 26  Maligayang pagdating sa isang bagong mundo! Sa...     4.0
# 28  Matagal na, matagal na tayong dalawa naghahana...     2.0
# 29      Hindi ko mapigilang ngumiti tuwing andiyan ka     5.0
# 30            Nais ko lang ay maging lahat para sa’yo     3.0
# 31  Kung ibibigay ko sa’yo ang buong buhay ko, aki...     4.0
# 33  Nangyayari ang stack overflow kapag labis ang ...     4.0
# 34  Pinapabilis ng database index ang pagkuha ng d...     3.0
# 35  Pinangangasiwaan ng kernel ang mga low-level n...     2.0
# 36  Dinadala ng address bus ang mga memory address...     3.0
# 37  Ang Jollibee ay isang sikat na kainan sa Pilip...     4.0
# 38  Tuwing bakasyon, binibisita ng mga Pilipino an...     3.0
# 39  Ginagamit ng mga Pilipino ang mga salitang “po...     4.0
# 40  Ang Adobo ay isa sa mga pinakasikat na ulam sa...     5.0
# 41  Ang pagiging hospitable ng mga Pilipino ay kil...     4.0
# 42  Mahal natin ang pagdidiwang ng piyesta and sal...     3.0
# 43  Ang adobo at sinigang ay ilan lamang sa masasa...     5.0
# 44  Bahagi ng ating kultura ang pagkain ng kanin s...     3.0
# 46  Ang nurse ay pinasok ang IV ng mali, kaya nagk...     2.0
# 47  Ang pasyente ay binigyan ng penicillin upang m...     5.0
# 48  Para makapagsimula ng fasting, tigilan ang pag...     3.0
# 49  Pagkatapos ng check-up, kailangang ma-admit ka...     3.0
# 51  Lagi ko sinisigurado na maglaan ng oras para s...     4.0
# 52  Isa sa layunin ng buhay ay ang tumulong sa kap...     5.0
# 53  Sa Spotify lang ako nakikinig ng music katulad...     4.0
# 54  Meron akong koleksyon ng mga non-fiction na li...     3.0
# 56  Ang pagseseryoso ng mga bagay na baliw ay isan...     5.0
# 57  Ang mga bagay sa labas mo ay salamin ng nasa l...     3.0
# 58  May ilang lalaking ipinanganak na katamtaman, ...     4.0
# 59  Sumakabilang-buhay si Inay ngayong araw. O bak...     2.0
# 60  Bumabalik ang alon sa karagatan, kung saan ito...     2.0
# 61  Ayaw mo na ng tsaa?! Parang sinabi mo na ring ...     5.0
# 62  Gusto ko imbitahin yung pinakabata kong anak p...     3.0
# 63  Wala nang respeto at pagmamahal yung tao para ...     5.0
#
#                                             Remarks 1  \
# 0   Accurate, fluent, and natural translation. Cap...
# 1   The translation is accurate. It was able to ca...
# 2   The translation of "identifies" as "kinikilala...
# 3   The translated text is natural and captures th...
# 4   flawed translation is close, but failed to tra...
# 5   Literal translation of an idiom, doesn't make ...
# 6   Accurate and understandable, good for formal/l...
# 7                     Perfect, natural, and accurate.
# 8                Excellent, accurate, and flows well.
# 9   Accurate, Fluent, Coherent, Complete, and capt...
# 10  Complete, and accurately translates the idioma...
# 11  Complete, and gramatically correct. However, t...
# 12  Accurate, Fluent, Coherent, Complete, and capt...
# 13  flawed translation takes "lies" as literal "be...
# 14  flawed translation takes "came in more colors"...
# 15     "Ang lalaking ito dito" should not have "dito"
# 16  "sumubok" might be better than "subukan" in th...
# 18  Good translation, gramatically correct, but th...
# 19  Perfect translation. Sounds natural as well fo...
# 20  Incoherent sentence due to trying to match eng...
# 21  Most of the translation is actually quite spot...
# 23  "mga oras at oras ng pinakamahusay na diskarte...
# 24  unnatural phrasing; "quintessential na karanas...
# 25  The translations are too literal; some of the ...
# 26  "installment" could be replaced with an apt fi...
# 28  translates you and me into tayo and the transl...
# 29     translation is accurate while sounding natural
# 30  fairly accurate translation but structure of s...
# 31  "sa akin" would be the most proper translation...
# 33  gramatically correct and serves the original m...
# 34  the phrase "pagkuha ng data" could be rewritte...
# 35  A lot of English terms are retained, which is ...
# 36  straightforward and generally accurate, tech-b...
# 37  Better to phrase it as “Ang Jollibee ay isa sa...
# 38  Better to use and phrase it as “Tuwing bakasyo...
# 39  Filipino not Pilipino. Change and take note of...
# 40                               Perfect translation.
# 41  kilala could be replaced with alam which would...
# 42  doesnt sound natural, could be better with Mah...
# 43  sounds natural, - is used properly for repeati...
# 44         doesnt sound natural and can be ambiguous.
# 46  translation feels too direct and it ended up h...
# 47  its clear, fluent, formal, and natural, it con...
# 48  "tigilan" is awkward in the context making the...
# 49  translation became to literal, "ma-admit", "ma...
# 51  translation overall has the same meaning but u...
# 52  translation is natural and meaning is well con...
# 53             decent translation but awkward wording
# 54  translation is understandable but phrasing and...
# 56  Captures tone and meaning well, using native-s...
# 57  Accurate and clear, though some of the poetic ...
# 58  It mimics the original text's rhythm until the...
# 59  The tone in the translated text feels too coll...
# 60           The wording feels awkward and unnatural.
# 61  Wording is natural and uses appropriate that p...
# 62  Not the best translation while its mostly corr...
# 63  The sentence flows very well and uses more inf...
#
#                                             Remarks 2  \
# 0   Just slight error due to the literal translati...
# 1   The translation would have been better if the ...
# 2   The translation would have been better if the ...
# 3   The translation didn't literally translated th...
# 4                                                None
# 5   Fails to capture the idiomatic meaning; sounds...
# 6   Effectively conveys legal terminology, correct...
# 7      Excellent, natural, and idiomatic translation.
# 8     Fluent, accurate, and retains original meaning.
# 9   Complete, and sounds natural. Captures the mea...
# 10      Good translation but conjugation is incorrect
# 11                 Idiom was not translated correctly
# 12                 Complete and grammatically correct
# 13                                               None
# 14                                               None
# 15  buzz-kill is not translated. also "totoong buz...
# 16  Changing adorable to "nakakabilib" (impressive...
# 18  Good translation that would be understood by n...
# 19  Accurate translation that would be used in eve...
# 20  Wrong verb-tense which makes the sentence soun...
# 21  No direct translation for dental in tagalog, s...
# 23  lexical error, “mas mahusay kaysa dati", liter...
# 24  stiff or overly formal tone, "binagong edisyon...
# 25  semantic errors and lexical errors, phrases li...
# 26      semantic error “Kaguluhan” (for “excitement”)
# 28  You and me' was translated as 'tayo', which mi...
# 29  The translation is correct and still sounds sm...
# 30  the meaning is mostly right, but the way the s...
# 31  Sa akin' might be a better choice, but overall...
# 33  \tToo literal; lacks clarification of technica...
# 34  \tAwkward phrasing; “pag-access sa disk” sound...
# 35  \tPoor localization; relies too much on untran...
# 36           Word-for-word; no effort to adapt terms.
# 37           - accurate translation\r\n- good grammar
# 38             - accurate translation\n- good grammar
# 39             - accurate translation\n- good grammar
# 40  - not sure if “sa” in “gawa sa” is the right w...
# 41                 kilala could be replace with sikat
# 42  salo-salo could be replaced with pagtitipon fo...
# 43                               accurate translation
# 44     gramatically correct but doesn't sound natural
# 46  Direct translation. There could've been a bett...
# 47  Correct translation, and it is not awkward to ...
# 48  The whole sentence sounds awkward, and the num...
# 49  The sentence is a bit awkward, especially some...
# 51  translation of sentence is "I ensure..." rathe...
# 52           correct and natural sounding translation
# 53                                    awkard phrasing
# 54  did not translate "large" and awkward translat...
# 56  It uses words that flow naturally and matches ...
# 57  The translation replaces a complex phrase with...
# 58  Preserves the structure and meaning well, thou...
# 59                 Doesn't feel natural. Too literal.
# 60  Extremely unnatural wording, especially on "ku...
# 61  Exceptionally natural translation. Even convey...
# 62  Although the meaning of the original sentence ...
# 63  Sounds very natural, capturing the sentiment c...
#
#                                              pred_raw  pred_rating
# 0   English Sentence: The children laughed and pla...            5
# 1   English Sentence: She took a break to gather h...            5
# 2   English Sentence: The algorithm efficiently id...            5
# 3   English Sentence: Data normalization helps imp...            4
# 4   English Sentence: alam mo ma'am masaya naman t...            1
# 5   English Sentence: It's raining cats and dogs.\...            5
# 6   English Sentence: The party of the first part ...            5
# 7   English Sentence: Thank you for coming to the ...            5
# 8   English Sentence: Despite her exhaustion, she ...            5
# 9   English Sentence: That designer bag costs an a...            4
# 10  English Sentence: I didn’t want to go to the d...            4
# 11  English Sentence: Mark accidentally let the ca...            2
# 12  English Sentence: I won’t be able to attend th...            5
# 13  English Sentence: Darkness is not heresy. It l...            2
# 14  English Sentence: This would be easier if bloo...            5
# 15  English Sentence: This guy right here is Shado...            5
# 16  English Sentence: Stealth is not your thing. B...            3
# 18  English Sentence: Cheddar cheese got its name ...            5
# 19  English Sentence: Which of the following tools...            5
# 20  English Sentence: With what would you use a "w...            3
# 21  English Sentence: Which of the following denta...            5
# 23  English Sentence: The Bloons are back and bett...            5
# 24  English Sentence: Sea of Thieves is a smash-hi...            5
# 25  English Sentence: The Binding of Isaac: Rebirt...            5
# 26  English Sentence: Welcome to a new world! In M...            5
# 28  English Sentence: For so long, you and me been...            5
# 29  English Sentence: I can't stop smiling when yo...            5
# 30  English Sentence: I just want to be your every...            5
# 31  English Sentence: If I give you all my life, w...            5
# 33  English Sentence: A stack overflow happens whe...            5
# 34  English Sentence: The database index speeds up...            5
# 35  English Sentence: The kernel handles low-level...            5
# 36  English Sentence: The address bus carries memo...            5
# 37  English Sentence: Jollibee is a famous fast fo...            5
# 38  English Sentence: Filipinos visit their relati...            5
# 39  English Sentence: Filipinos often use the expr...            5
# 40  English Sentence: Adobo is one of the most pop...            5
# 41  English Sentence: The hospitability of Filipin...            5
# 42  English Sentence: We love to celebrate fiestas...            5
# 43  English Sentence: Adobo and sinigang are just ...            5
# 44  English Sentence: Eating rice with almost ever...            5
# 46  English Sentence: The nurse inserted the IV in...            5
# 47  English Sentence: The patient was given penici...            5
# 48  English Sentence: To be able to start fasting,...            4
# 49  English Sentence: After being checked up, you ...            5
# 51  English Sentence: I always make it a priority ...            5
# 52  English Sentence: One of the purposes of life ...            5
# 53  English Sentence: I exclusively use Spotify to...            5
# 54  English Sentence: I have a large collection of...            4
# 56  English Sentence: Taking crazy things seriousl...            5
# 57  English Sentence: Things outside you are proje...            4
# 58  English Sentence: Some men are born mediocre, ...            4
# 59  English Sentence: Mother died today. Or maybe ...            5
# 60  English Sentence: The wave returns to the ocea...            5
# 61  English Sentence: Sick of tea?! That's like be...            5
# 62  English Sentence: I wanted to invite my younge...            5
# 63  English Sentence: That person has no more resp...            5

# %% [markdown]
# Measure performance of prompt-engineered LLM using standard metrics (accuracy, precision, recall, f1-score)

# %%
y_true = test_df_prompt_engineered['Rating'].tolist()
y_pred = test_df_prompt_engineered['pred_rating'].tolist()

measure_standard_metrics(y_true, y_pred)
# Out:
# Accuracy: 0.263
# Macro Precision: 0.210
# Macro Recall: 0.220
# Macro F1-score: 0.153
#
# Detailed per-rating breakdown:
#
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00         4
#          2.0       0.50      0.10      0.17        10
#          3.0       0.00      0.00      0.00        15
#          4.0       0.29      0.14      0.19        14
#          5.0       0.27      0.86      0.41        14
#
#     accuracy                           0.26        57
#    macro avg       0.21      0.22      0.15        57
# weighted avg       0.22      0.26      0.18        57
